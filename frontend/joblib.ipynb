# %%
import joblib
model = joblib.load(r"C:\Users\Siddhi Thorat\Downloads\ML_FarmerCreditRisk_updated\models\best_model.pkl")
print(model)
# Out:
# LogisticRegression(C=0.8, class_weight='balanced', max_iter=2000,
#                    multi_class='deprecated', random_state=42)

# %%
import joblib
model = joblib.load(r"C:\Users\Siddhi Thorat\Downloads\ML_FarmerCreditRisk_updated\models\feature_cols.pkl")
print(model)
# Out:
# ['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'TotalIncome', 'TotalIncome_log', 'LoanAmount_log', 'EMI', 'BalanceIncome', 'Debt_to_Income', 'Income_per_Person', 'LoanToIncome_ratio', 'ApplicantIncome_bin', 'LoanAmount_bin', 'TotalIncome_bin']
